# %%
import pandas as pd
df = pd.read_csv("insurance.csv")

# %%
print(df.head())
df.tail()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.isnull().sum()
#all the dataset is fine , so no issues
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['Hospital charges']=df['charges']
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       Hospital charges
# 0          16884.92400
# 1           1725.55230
# 2           4449.46200
# 3          21984.47061
# 4           3866.85520
# ...

# %%
df = df.drop(columns=['charges'])

df
# Out:
#       age     sex     bmi  children smoker     region  Hospital charges
# 0      19  female  27.900         0    yes  southwest       16884.92400
# 1      18    male  33.770         1     no  southeast        1725.55230
# 2      28    male  33.000         3     no  southeast        4449.46200
# 3      33    male  22.705         0     no  northwest       21984.47061
# 4      32    male  28.880         0     no  northwest        3866.85520
# ...   ...     ...     ...       ...    ...        ...               ...
# 1333   50    male  30.970         3     no  northwest       10600.54830
# 1334   18  female  31.920         0     no  northeast        2205.98080
# 1335   18  female  36.850         0     no  southeast        1629.83350
# 1336   21  female  25.800         0     no  southwest        2007.94500
# 1337   61  female  29.070         0    yes  northwest       29141.36030
#
# [1338 rows x 7 columns]

# %%
df.replace({'sex': {'male': 0, 'female': 1}}, inplace=True)
df.replace({'smoker': {'no': 0, 'yes': 1}}, inplace=True)
df.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)
df
# Out:
#       age  sex     bmi  children  smoker  region  Hospital charges
# 0      19    1  27.900         0       1       1       16884.92400
# 1      18    0  33.770         1       0       0        1725.55230
# 2      28    0  33.000         3       0       0        4449.46200
# 3      33    0  22.705         0       0       3       21984.47061
# 4      32    0  28.880         0       0       3        3866.85520
# ...   ...  ...     ...       ...     ...     ...               ...
# 1333   50    0  30.970         3       0       3       10600.54830
# 1334   18    1  31.920         0       0       2        2205.98080
# 1335   18    1  36.850         0       0       0        1629.83350
# 1336   21    1  25.800         0       0       1        2007.94500
# 1337   61    1  29.070         0       1       3       29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region  Hospital charges
# count  1338.000000       1338.000000
# mean      1.455904      13270.422265
# std       1.130888      12110.011237
# min       0.000000       1121.873900
# 25%       0.000000       4740.287150
# 50%       1.000000       9382.033000
# 75%       2.000000      16639.912515
# ...

# %%
x = df.iloc[:,:6]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    0  33.770         1       0       0
# 2      28    0  33.000         3       0       0
# 3      33    0  22.705         0       0       3
# 4      32    0  28.880         0       0       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       3
# 1334   18    1  31.920         0       0       2
# 1335   18    1  36.850         0       0       0
# 1336   21    1  25.800         0       0       1
# 1337   61    1  29.070         0       1       3
#
# [1338 rows x 6 columns]

# %%
y = df.loc[:,['Hospital charges']]
y
# Out:
#       Hospital charges
# 0          16884.92400
# 1           1725.55230
# 2           4449.46200
# 3          21984.47061
# 4           3866.85520
# ...                ...
# 1333       10600.54830
# 1334        2205.98080
# 1335        1629.83350
# 1336        2007.94500
# 1337       29141.36030
#
# [1338 rows x 1 columns]

# %%
#training the data taking test-size as 10 percent as we will train the 
#data with more size , better accuracy
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=0)

# %%
#taking the predicted output using teh algorithms .
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

#object initialise
log = LinearRegression()
dcs = DecisionTreeRegressor()
#fitting the data inside and performing the training
log.fit(x_train,y_train)
dcs.fit(x_train,y_train)

pred1 = log.predict(x_test)
pred2 = dcs.predict(x_test)


print(f"Predict salary for Linear Regression {pred1} & accuracy is {r2_score(y_test,pred1)}")
# Out:
# Predict salary for Linear Regression [[11295.02602759]
#  [ 9499.16398208]
#  [38215.0602703 ]
#  [16372.12097258]
#  [ 7321.21503703]
#  [ 3725.04160037]
#  [ 1297.03394987]
#  [14592.39262329]
#  [ 9297.785253  ]
#  [ 7749.34011822]
#  [ 4364.05296833]
#  [10607.64868059]
#  [ 8956.39914211]
#  [ 3856.75552755]
#  [28082.01124671]
#  [10777.76472726]
#  [11584.7132758 ]
#  [ 5728.95359701]
#  [ 8493.06959168]
#  [26704.7703539 ]
#  [33892.81184929]
#  [14582.82767903]
#  [11407.57430837]
#  [32085.17960738]
#  [ 4066.26468164]
#  [ 8815.85444163]
#  [  928.41808101]
#  [ 9797.03610476]
#  [ 3809.56969673]
#  [10670.14583618]
#  [ 9315.95292272]
#  [39834.09891886]
#  [15704.56198416]
#  [13893.43699359]
#  [24489.06968182]
#  [ 4867.26174   ]
#  [12490.31190371]
#  [30730.75526103]
#  [33715.60361707]
#  [ 3754.56307371]
#  [ 3788.44434603]
#  [ 3965.41527942]
#  [30154.80330107]
#  [39592.3704279 ]
#  [27623.78775654]
#  [ 5320.85135833]
#  [10671.36480321]
#  [ 8106.85743856]
# ...

# %%
print(f"Predict salary for Decision Tree {pred2} & accuracy is {r2_score(y_test,pred2)}")
# Out:
# Predict salary for Decision Tree [10797.3362   8871.1517  44202.6536  12648.7034   8688.85885 21984.47061
#   2196.4732  10848.1343   7281.5056   6128.79745  7228.21565  9910.35985
#   8233.0975   4992.3764  20009.63365 10560.4917  12323.936    4661.28635
#   6548.19505 33907.548   24667.419   12269.68865 10797.3362  24535.69855
#   1391.5287   6113.23105  2680.9493   7954.517    3757.8448   8733.22925
#   7281.5056  47896.79135 21797.0004  10601.63225 15817.9857   3736.4647
#   8825.086   37165.1638  39983.42595  1391.5287  21984.47061  2866.091
#  21659.9301  44641.1974  36307.7983   3579.8287  10560.4917   6664.68595
#   5354.07465 27117.99378  3046.062   22493.65964 37829.7242  60021.39897
#  11856.4115  19673.33573  2137.6536   8835.26495  9788.8659  14349.8544
#   1842.519   46130.5265  14007.222   25333.33284 26392.26029  9875.6804
#  33907.548   39983.42595 11884.04858  6796.86325 12233.828   10965.446
#  19040.876   13887.204   13204.28565 12233.828    7623.518    7441.501
# ...

# %%
import seaborn as pt

# %%
axs = pt.countplot(data=df, x='children', palette='coolwarm')
axs
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3060\1652452996.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axs = pt.countplot(data=df, x='children', palette='coolwarm')
# <AxesSubplot:xlabel='children', ylabel='count'>
